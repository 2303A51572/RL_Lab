# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51572/RL_Lab/blob/main/RL_assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Part A – Machine Initialization
machines = ['A', 'B', 'C']

# Number of machines and plays
M = 3
N_play = 10
epsilon = 0.2

# Part B – Initialize knowledge tables
# N = number of times each machine is selected
# R = total reward obtained from each machine
# Q = estimated average reward of each machine
N = {machine: 0 for machine in machines}
R = {machine: 0 for machine in machines}
Q = {machine: 0.0 for machine in machines}

print("Initial Tables")
print("N =", N)
print("R =", R)
print("Q =", Q)

# Part C – Modified Epsilon-Greedy Decision
for play in range(1, N_play + 1):

    # Generate random number between 0 and 1
    r = random.random()

    # Find machine with highest Q-value
    max_q = max(Q.values())
    highest_machine = max(Q, key=Q.get)

    if r < epsilon:
        # Exploration:
        # Select randomly from machines except highest Q machine
        exploration_machines = [
            machine for machine in machines
            if machine != highest_machine
        ]

        selected_machine = random.choice(exploration_machines)
        decision = "Exploration"

    else:
        # Exploitation:
        # Select machine with highest Q-value
        selected_machine = highest_machine
        decision = "Exploitation"

    # Part D – Reward Collection
    print("\nPlay", play)
    print("Random number:", round(r, 4))
    print("Decision:", decision)
    print("Selected machine:", selected_machine)

    reward = float(input("Enter reward: "))

    # Part E – Q-Value Update
    N[selected_machine] += 1
    R[selected_machine] += reward

    # Incremental sample-average formula:
    # Q(a) = Q(a) + [R - Q(a)] / N(a)
    Q[selected_machine] = (
        Q[selected_machine]
        + (reward - Q[selected_machine]) / N[selected_machine]
    )

    print("Updated N:", N)
    print("Updated R:", R)
    print("Updated Q:", {m: round(Q[m], 2) for m in machines})


# Part F – Final Results
print("\n" + "=" * 50)
print("FINAL RESULTS")
print("=" * 50)

print("\nMachine\tParticipation Count (N)\tTotal Reward (R)\tQ-Value")

for machine in machines:
    print(
        f"{machine}\t\t{N[machine]}\t\t\t{R[machine]:.2f}\t\t{Q[machine]:.2f}"
    )

# Total reward received
total_reward = sum(R.values())

print("\nTotal Reward Received:", total_reward)

# Best machine
best_machine = max(Q, key=Q.get)

print("Best Estimated Machine:", best_machine)
print("Best Q-Value:", round(Q[best_machine], 2))
# Out:
# Initial Tables
# N = {'A': 0, 'B': 0, 'C': 0}
# R = {'A': 0, 'B': 0, 'C': 0}
# Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}
#
# Play 1
# Random number: 0.5029
# Decision: Exploitation
# Selected machine: A
# Enter reward: 7
# Updated N: {'A': 1, 'B': 0, 'C': 0}
# Updated R: {'A': 7.0, 'B': 0, 'C': 0}
# Updated Q: {'A': 7.0, 'B': 0.0, 'C': 0.0}
#
# Play 2
# Random number: 0.9588
# Decision: Exploitation
# Selected machine: A
# Enter reward: 5
# Updated N: {'A': 2, 'B': 0, 'C': 0}
# Updated R: {'A': 12.0, 'B': 0, 'C': 0}
# Updated Q: {'A': 6.0, 'B': 0.0, 'C': 0.0}
#
# Play 3
# Random number: 0.057
# Decision: Exploration
# Selected machine: C
# Enter reward: 8
# Updated N: {'A': 2, 'B': 0, 'C': 1}
# Updated R: {'A': 12.0, 'B': 0, 'C': 8.0}
# Updated Q: {'A': 6.0, 'B': 0.0, 'C': 8.0}
#
# Play 4
# Random number: 0.0255
# Decision: Exploration
# Selected machine: A
# Enter reward: 4
# Updated N: {'A': 3, 'B': 0, 'C': 1}
# Updated R: {'A': 16.0, 'B': 0, 'C': 8.0}
# ...
