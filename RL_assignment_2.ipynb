# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51572/RL_Lab/blob/main/RL_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

machines = ['A', 'B', 'C']
N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': [], 'B': [], 'C': []}
Q = {'A': 0, 'B': 0, 'C': 0}

epsilon = 0.2

for i in range(10):
    r = random.random()

    if r < epsilon:
        m = random.choice(machines)
        print("Exploration")
    else:
        m = max(Q, key=Q.get)
        print("Exploitation")

    print("Play with machine", m)
    reward = float(input("Enter reward: "))

    N[m] += 1
    R[m].append(reward)

    Q[m] = Q[m] + (reward - Q[m]) / N[m]

print("\nN Table:", N)
print("R Table:", R)
print("Q Table:", Q)
# Out:
# Exploration
# Play with machine A
# Enter reward: 3
# Exploitation
# Play with machine A
# Enter reward: 4
# Exploration
# Play with machine C
# Enter reward: 8
# Exploration
# Play with machine B
# Enter reward: 8
# Exploitation
# Play with machine B
# Enter reward: 9
# Exploitation
# Play with machine B
# Enter reward: 3
# Exploitation
# Play with machine C
# Enter reward: 5
# Exploitation
# Play with machine B
# Enter reward: 9
# Exploitation
# Play with machine B
# Enter reward: 5
# Exploitation
# Play with machine B
# Enter reward: 7
#
# N Table: {'A': 2, 'B': 6, 'C': 2}
# R Table: {'A': [3.0, 4.0], 'B': [8.0, 9.0, 3.0, 9.0, 5.0, 7.0], 'C': [8.0, 5.0]}
# Q Table: {'A': 3.5, 'B': 6.833333333333333, 'C': 6.5}
